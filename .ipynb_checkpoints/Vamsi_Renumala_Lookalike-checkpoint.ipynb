# %%
import numpy as np
import pandas as pd

# %%
customers = pd.read_csv('Customers.csv')
products = pd.read_csv('Products.csv')
transactions = pd.read_csv('Transactions.csv')

# %%
merged_data = pd.read_csv('merged_data.csv')

# %%
merged_data.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue  Price_x     CustomerName         Region  SignupDate  \
# 0      300.68   300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68   300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68   300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36   300.68  Travis Campbell  South America  2024-04-11
# 4      902.04   300.68    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category  Price_y    Month
# 0  ComfortLiving Bluetooth Speaker  Electronics   300.68  2024-08
# 1  ComfortLiving Bluetooth Speaker  Electronics   300.68  2024-05
# 2  ComfortLiving Bluetooth Speaker  Electronics   300.68  2024-04
# 3  ComfortLiving Bluetooth Speaker  Electronics   300.68  2024-03
# 4  ComfortLiving Bluetooth Speaker  Electronics   300.68  2024-03

# %%
customer_features = merged_data.groupby('CustomerID').agg({'TotalValue': 'sum',
                                                            'Quantity': 'sum',
                                                            'Category': lambda x: x.mode()[0],
                                                            'Region': 'first'
                                                        }).reset_index()

# %%
customer_features = pd.get_dummies(customer_features, columns=['Category', 'Region'], drop_first=True)

# %%
customer_features.head()
# Out:
#   CustomerID  TotalValue  Quantity  Category_Clothing  Category_Electronics  \
# 0      C0001     3354.52        12              False                  True
# 1      C0002     1862.74        10               True                 False
# 2      C0003     2725.38        14              False                 False
# 3      C0004     5354.88        23              False                 False
# 4      C0005     2034.24         7              False                  True
#
#    Category_Home Decor  Region_Europe  Region_North America  \
# 0                False          False                 False
# 1                False          False                 False
# 2                 True          False                 False
# 3                False          False                 False
# 4                False          False                 False
#
#    Region_South America
# 0                  True
# 1                 False
# 2                  True
# 3                  True
# 4                 False

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(customer_features.drop(columns=['CustomerID']))
similarity_df = pd.DataFrame(similarity_matrix, index=customer_features['CustomerID'], columns=customer_features['CustomerID'])

# %%
similarity_matrix.shape
# Out:
# (199, 199)

# %%
similarity_matrix[0]
# Out:
# array([1.        , 0.99999816, 0.99999867, 0.99999969, 0.99999993,
#        0.99999968, 0.99999984, 0.99999925, 0.99999864, 0.99999376,
#        0.99999995, 0.99999993, 0.99999977, 0.99998642, 0.99999953,
#        0.99999935, 0.99999954, 0.99999987, 0.99999875, 0.99999901,
#        0.99999981, 0.99999983, 0.99999952, 0.99999983, 0.99999864,
#        0.9999999 , 0.9999993 , 0.99999994, 0.99999755, 0.9999986 ,
#        0.99999882, 0.99999183, 0.99987697, 0.9999979 , 0.99999984,
#        0.99999954, 0.99999982, 0.999999  , 0.99999977, 0.99999932,
#        0.99999988, 0.99999915, 0.99999842, 0.99999887, 0.99999992,
#        0.99999988, 0.9999994 , 0.99999989, 0.99999264, 0.99999943,
#        0.99999964, 0.99999977, 0.99999986, 0.99999977, 0.9999997 ,
#        0.99999984, 0.99999989, 0.99999299, 0.99999971, 0.99963837,
#        0.9999994 , 0.99999869, 0.99999965, 0.99999982, 0.99999989,
#        0.99999919, 0.99999984, 0.99999993, 0.99999989, 0.99999983,
#        0.99999886, 0.99999961, 0.99999898, 0.9999994 , 0.99999916,
#        0.99999921, 0.9999874 , 0.99999868, 0.99999957, 0.99999924,
#        0.9999998 , 0.9999998 , 0.99999446, 0.99999952, 0.99999956,
#        0.99999913, 0.99999991, 0.99999919, 0.99999941, 0.99999987,
#        0.99999609, 0.99999982, 0.99999989, 0.999991  , 0.99999972,
#        0.99999954, 0.99996666, 0.99999944, 0.99999983, 0.99999957,
#        0.99999991, 0.99999997, 0.99999948, 0.99999986, 0.9999999 ,
#        0.9999995 , 0.99999988, 0.99999989, 0.99999734, 0.99999913,
#        0.99998938, 0.99999983, 0.99999944, 0.99999983, 0.99999943,
#        0.99999976, 0.9999997 , 0.99999973, 0.99999839, 0.99999999,
#        0.99998866, 0.99999987, 0.99999965, 0.99999947, 0.99999983,
#        0.99999969, 0.99999989, 0.99999903, 0.99999982, 0.99999811,
#        0.99999978, 0.99999949, 0.99999987, 0.99999697, 0.99999978,
#        0.99999903, 0.99999992, 0.99999975, 0.99999987, 0.9999995 ,
#        0.99999935, 0.99999902, 0.99999989, 0.99999606, 0.99999989,
#        0.99999984, 0.99999927, 0.99999995, 0.99999984, 0.99999745,
#        0.99987934, 0.99999972, 0.99999995, 0.99999973, 0.99999986,
#        0.9999999 , 0.99999825, 0.99999925, 0.99999975, 0.99999907,
#        0.99999953, 0.99999978, 0.99999989, 0.99999975, 0.99999954,
#        0.99999924, 0.99999981, 0.99999923, 0.9999996 , 0.99999973,
#        0.99999973, 0.99999924, 0.9999999 , 0.99999979, 0.99999973,
#        0.99999849, 0.99999991, 0.99999981, 0.9999998 , 0.99999959,
#        0.99999986, 0.99999974, 0.99999994, 0.99999942, 0.99999984,
#        0.99999924, 0.99999978, 0.9999996 , 0.99999938, 0.99999995,
#        0.99999993, 0.99999991, 0.99999988, 0.99999972, 0.99999919,
#        0.9999992 , 0.9999987 , 0.99999934, 0.99999987])

# %%
lookalikes = {}
for customer in customer_features['CustomerID'][:20]:
    similar_customers = similarity_df[customer].sort_values(ascending=False).iloc[1:4]
    lookalikes[customer] = list(zip(similar_customers.index, similar_customers.values))

# %%
lookalike_df = pd.DataFrame({
    'CustomerID': lookalikes.keys(),
    'Lookalikes': [str(v) for v in lookalikes.values()]
})
lookalike_df.to_csv("Vamsi_Renumala_Lookalike.csv", index=False)
